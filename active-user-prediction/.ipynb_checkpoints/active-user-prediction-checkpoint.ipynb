# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('1905-ML_Game1_data.csv', header=None)

# %%
size = len(df)

# %%
ts = pd.date_range(end='5/10/2019 10:00:00', periods=size, freq='15min')
ts
# Out:
# DatetimeIndex(['2019-02-19 01:45:00', '2019-02-19 02:00:00',
#                '2019-02-19 02:15:00', '2019-02-19 02:30:00',
#                '2019-02-19 02:45:00', '2019-02-19 03:00:00',
#                '2019-02-19 03:15:00', '2019-02-19 03:30:00',
#                '2019-02-19 03:45:00', '2019-02-19 04:00:00',
#                ...
#                '2019-05-10 07:45:00', '2019-05-10 08:00:00',
#                '2019-05-10 08:15:00', '2019-05-10 08:30:00',
#                '2019-05-10 08:45:00', '2019-05-10 09:00:00',
#                '2019-05-10 09:15:00', '2019-05-10 09:30:00',
#                '2019-05-10 09:45:00', '2019-05-10 10:00:00'],
#               dtype='datetime64[ns]', length=7714, freq='15T')

# %%
df = df.rename(columns={0:'y'})

# %%
df['ts'] = ts

# %%
df['y'] = (df['y'] - df['y'].mean()) / (df['y'].std())
df
# Out:
#              y                  ts
# 0    -0.435324 2019-02-19 01:45:00
# 1    -0.606050 2019-02-19 02:00:00
# 2    -0.458173 2019-02-19 02:15:00
# 3    -0.422923 2019-02-19 02:30:00
# 4    -0.359220 2019-02-19 02:45:00
# 5    -0.435834 2019-02-19 03:00:00
# 6    -0.400839 2019-02-19 03:15:00
# 7    -0.765140 2019-02-19 03:30:00
# 8    -0.797162 2019-02-19 03:45:00
# 9    -0.922871 2019-02-19 04:00:00
# 10   -0.918369 2019-02-19 04:15:00
# 11   -0.926523 2019-02-19 04:30:00
# 12   -1.054185 2019-02-19 04:45:00
# 13   -0.984791 2019-02-19 05:00:00
# 14   -1.098608 2019-02-19 05:15:00
# 15   -1.021144 2019-02-19 05:30:00
# 16   -1.142861 2019-02-19 05:45:00
# 17   -1.133433 2019-02-19 06:00:00
# 18   -1.067351 2019-02-19 06:15:00
# 19   -1.104299 2019-02-19 06:30:00
# 20   -1.165625 2019-02-19 06:45:00
# 21   -1.106592 2019-02-19 07:00:00
# 22   -1.112538 2019-02-19 07:15:00
# 23   -1.047985 2019-02-19 07:30:00
# 24   -0.931280 2019-02-19 07:45:00
# 25   -0.895096 2019-02-19 08:00:00
# 26   -0.809138 2019-02-19 08:15:00
# 27   -0.954043 2019-02-19 08:30:00
# 28   -0.808034 2019-02-19 08:45:00
# 29   -0.716046 2019-02-19 09:00:00
# ...        ...                 ...
# 7684 -0.710355 2019-05-10 02:45:00
# 7685 -0.521792 2019-05-10 03:00:00
# 7686 -0.733798 2019-05-10 03:15:00
# 7687 -0.488326 2019-05-10 03:30:00
# 7688 -0.760468 2019-05-10 03:45:00
# 7689 -0.878193 2019-05-10 04:00:00
# 7690 -0.692688 2019-05-10 04:15:00
# 7691 -0.826805 2019-05-10 04:30:00
# 7692 -0.789942 2019-05-10 04:45:00
# 7693 -0.855345 2019-05-10 05:00:00
# 7694 -0.776012 2019-05-10 05:15:00
# 7695 -0.623293 2019-05-10 05:30:00
# 7696 -0.834874 2019-05-10 05:45:00
# 7697 -1.071768 2019-05-10 06:00:00
# 7698 -0.948352 2019-05-10 06:15:00
# 7699 -0.910555 2019-05-10 06:30:00
# 7700 -1.008489 2019-05-10 06:45:00
# 7701 -1.062339 2019-05-10 07:00:00
# 7702 -0.906478 2019-05-10 07:15:00
# 7703 -0.832326 2019-05-10 07:30:00
# 7704 -0.699313 2019-05-10 07:45:00
# 7705 -0.700672 2019-05-10 08:00:00
# 7706 -0.696170 2019-05-10 08:15:00
# 7707 -0.922106 2019-05-10 08:30:00
# 7708 -0.881845 2019-05-10 08:45:00
# 7709 -1.015114 2019-05-10 09:00:00
# 7710 -0.917180 2019-05-10 09:15:00
# 7711 -0.998806 2019-05-10 09:30:00
# 7712 -0.914377 2019-05-10 09:45:00
# 7713 -0.870718 2019-05-10 10:00:00
#
# [7714 rows x 2 columns]

# %%
from fbprophet import Prophet
m = Prophet()
m.fit(df)
future = m.make_future_dataframe(periods=200, freq='15min')
future.tail()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-77-8ad03fded5a9> in <module>
# ----> 1 from fbprophet import Prophet
#       2 m = Prophet()
#       3 m.fit(df)
#       4 future = m.make_future_dataframe(periods=200, freq='15min')
#       5 future.tail()
#
# C:\program\anaconda3\lib\site-packages\fbprophet\__init__.py in <module>
#       6 # of patent rights can be found in the PATENTS file in the same directory.
#       7
# ----> 8 from fbprophet.forecaster import Prophet
#       9
#      10 __version__ = '0.4'
#
# C:\program\anaconda3\lib\site-packages\fbprophet\forecaster.py in <module>
#      15 import numpy as np
#      16 import pandas as pd
# ---> 17 import pystan  # noqa F401
#      18
#      19 from fbprophet.diagnostics import prophet_copy
#
# C:\program\anaconda3\lib\site-packages\pystan\__init__.py in <module>
#       7 import logging
#       8
# ----> 9 from pystan.api import stanc, stan
#      10 from pystan.misc import read_rdump, stan_rdump, stansummary
#      11 from pystan.model import StanModel
#
# C:\program\anaconda3\lib\site-packages\pystan\api.py in <module>
#      11 import warnings
#      12
# ---> 13 import pystan._api  # stanc wrapper
#      14 from pystan._compat import string_types, PY2
#      15 from pystan.model import StanModel
#
# ModuleNotFoundError: No module named 'pystan._api'

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-7a1f8307e379> in <module>
# ----> 1 forecast = m.predict(future)
#       2 forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
#
# NameError: name 'm' is not defined

# %%
fig1 = m.plot(forecast)

# %%
m.plot_components(forecast)

# %%
x1 = forecast['ds']
y1 = forecast['yhat']
y2 = forecast['yhat_lower']
y3 = forecast['yhat_upper']
plt.plot(x1,y1)
plt.plot(x1,y2)
plt.plot(x1,y3)
plt.show()
